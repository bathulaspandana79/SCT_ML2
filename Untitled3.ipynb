# %%
# Step 1: Install required libraries (run in Jupyter Notebook cell)
# !pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.5.1)
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-learn in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Spandana\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.3 MB 1.8 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.3 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.3 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.3 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.3 MB 1.3 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.3 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.4/9.3 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.6/9.3 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.3 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.3 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.1/9.3 MB 1.1 MB/s eta 0:00:06
#    ------------- -------------------------- 3.1/9.3 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 3.4/9.3 MB 1.1 MB/s eta 0:00:06
#    ---------------- ----------------------- 3.9/9.3 MB 1.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.9/9.3 MB 1.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.1 MB/s eta 0:00:05
#    -------------------- ------------------- 4.7/9.3 MB 1.1 MB/s eta 0:00:05
#    --------------------- ------------------ 5.0/9.3 MB 1.1 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.3 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 5.8/9.3 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 5.8/9.3 MB 1.2 MB/s eta 0:00:04
#    -------------------------- ------------- 6.3/9.3 MB 1.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 6.8/9.3 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 7.1/9.3 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 7.6/9.3 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 7.9/9.3 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 8.4/9.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 1.3 MB/s  0:00:07
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 802.2 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.2 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 2.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.2 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.2 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.2 MB 1.7 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.2 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.2 MB 1.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 1.8/7.2 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 2.6/7.2 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.2 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.2 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.2 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 2.9/7.2 MB 1.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.1/7.2 MB 1.1 MB/s eta 0:00:04
#    ------------------ --------------------- 3.4/7.2 MB 1.0 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.2 MB 1.1 MB/s eta 0:00:04
#    --------------------- ------------------ 3.9/7.2 MB 765.2 kB/s eta 0:00:05
#    --------------------- ------------------ 3.9/7.2 MB 765.2 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.2/7.2 MB 753.0 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.2/7.2 MB 753.0 kB/s eta 0:00:05
#    ------------------------ --------------- 4.5/7.2 MB 755.9 kB/s eta 0:00:04
#    ------------------------ --------------- 4.5/7.2 MB 755.9 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.2 MB 731.6 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.2 MB 731.6 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.2 MB 731.6 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.2 MB 731.6 kB/s eta 0:00:04
#    --------------------------- ------------ 5.0/7.2 MB 690.2 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.2/7.2 MB 701.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 5.2/7.2 MB 701.6 kB/s eta 0:00:03
#    ------------------------------ --------- 5.5/7.2 MB 707.9 kB/s eta 0:00:03
#    ------------------------------ --------- 5.5/7.2 MB 707.9 kB/s eta 0:00:03
#    ------------------------------ --------- 5.5/7.2 MB 707.9 kB/s eta 0:00:03
#    ------------------------------- -------- 5.8/7.2 MB 680.7 kB/s eta 0:00:03
#    ------------------------------- -------- 5.8/7.2 MB 680.7 kB/s eta 0:00:03
#    --------------------------------- ------ 6.0/7.2 MB 673.4 kB/s eta 0:00:02
#    ------------------------------------ --- 6.6/7.2 MB 717.4 kB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 726.9 kB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 726.9 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 731.2 kB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 731.2 kB/s  0:00:09
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2

# %% [markdown]
# # Customer Segmentation Using K-means Clustering

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Mall_Customers.csv")
print(data.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(4,3))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_scaled)

# %%
data['Cluster'] = y_kmeans

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=y_kmeans, palette='Set1', s=100)
plt.title('Customer Segments (K-Means)')
plt.xlabel('Annual Income (scaled)')
plt.ylabel('Spending Score (scaled)')
plt.show()

# %%
print(data.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4
